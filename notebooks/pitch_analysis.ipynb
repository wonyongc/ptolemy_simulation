# %% [markdown]
# # Pitch Analysis Example
# Loads pitchanalysis exports and plots mean pitch vs z.

# %%
from pathlib import Path
from ptolemy_simulation.analysis.pitch import aggregate_pitch_files, plot_pitch

files = sorted(Path('generated/analysis/pitch_inputs').glob('*.txt'))
z, avg = aggregate_pitch_files(files)
plot_pitch(z, avg, Path('generated/analysis/pitch_notebook.png'))
print('points:', len(z))
